# %% [markdown]
# <a href="https://colab.research.google.com/github/dbala12/Daranee-Balachandar-Jour652/blob/main/j6_database.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-generativeai google-auth-oauthlib google-api-python-client gspread pypdf
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.11/dist-packages (0.8.5)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.11/dist-packages (1.2.2)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (2.177.0)
# Requirement already satisfied: gspread in /usr/local/lib/python3.11/dist-packages (6.2.1)
# Collecting pypdf
#   Downloading pypdf-5.9.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.25.1)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.38.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.11.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.14.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.2.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (0.4.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.74.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2025.7.14)
# Downloading pypdf-5.9.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.2/313.2 kB 5.4 MB/s eta 0:00:00
# Installing collected packages: pypdf
# Successfully installed pypdf-5.9.0

# %%
import google.generativeai as genai
from google.colab import auth
import gspread
from google.auth import default
import pandas as pd
from pypdf import PdfReader
import time
import json
import io # We need this for handling PDF raw data

# --- CONFIGURATION ---
GOOGLE_API_KEY = 'AIzaSyAGCg-x8rB95NTyKrLZ08bBsaxS1ySDei4' # Paste your Gemini API key here
# ---------------------

# Configure the Gemini API
genai.configure(api_key=GOOGLE_API_KEY)

# Authorize access to Google Drive and Google Sheets
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# %%
# This is the detailed instruction we will give to the AI for each document.
MASTER_PROMPT = """
You are an expert legal research assistant tasked with extracting information from court documents related to the January 6th Capitol riot.

Your goal is to identify EVERY law enforcement officer, including U.S. Capitol Police officers and Metropolitan Police Department officers mentioned by name or initials as being present at the U.S. Capitol on January 6, 2021 and categorize whether they were assaulted or injured on that day.

From the provided text below, extract the following details for each officer identified:
1.  full_name: The officer's full name if available.
2.  initials_identifier: The officer's initials (e.g., "A.B.") or identifier (e.g., "Officer #1"). Leave blank if a full name is available.
3.  agency: The officer's law enforcement agency (e.g., "U.S. Capitol Police," "Metropolitan Police Department"). If not specified, state "Unknown."
4.  job_title: The officer's title (e.g., "Sergeant," "Officer," "Agent") if mentioned.
5.  assaulted: Determine if the officer was assaulted or injured based on the text.
    * If it is CLEAR the officer was assaulted, injured, pushed, sprayed, struck, or otherwise physically harmed, state "assaulted".
    * If there is NO mention of the officer being assaulted or injured, state "none".
    * If it is UNCLEAR or ambiguous whether the officer was assaulted or injured, state "unknown".
6.  description_of_assault: If 'assaulted' is "assaulted", provide a brief, direct quote or summary of the assault or injury described in the text. If 'assaulted' is "none" or "unknown", leave this blank.
7.  location_assault_occurred: If 'assaulted' is "assaulted", specify the exact location of the injury or assault (e.g., "Lower West Terrace tunnel," "The Rotunda doors," "East Front steps") if explicitly mentioned. If 'assaulted' is "none" or "unknown", leave this blank.

Do not include officers who are just mentioned as being present but without any context of their role or presence during the events of January 6th. Focus on officers whose presence or actions are directly related to the events within the Capitol Building or its immediate vicinity on January 6, 2021, as described in the document.

Provide the output as a JSON array of objects. Each object should represent one officer. If no officers are identified as being present with relevant details, return an empty array [].

Here is an example of the desired output format:
[
  {
    "full_name": "Caroline Edwards",
    "initials_identifier": "",
    "agency": "U.S. Capitol Police",
    "job_title": "Officer",
    "assaulted": "assaulted",
    "description_of_assault": "pushed from behind, causing her to hit her head on the stairs and lose consciousness.",
    "location_assault_occurred": "West Front"
  },
  {
    "full_name": "John Doe",
    "initials_identifier": "J.D.",
    "agency": "Metropolitan Police Department",
    "job_title": "Sergeant",
    "assaulted": "unknown",
    "description_of_assault": "",
    "location_assault_occurred": ""
  },
  {
    "full_name": "Jane Smith",
    "initials_identifier": "",
    "agency": "U.S. Capitol Police",
    "job_title": "Officer",
    "assaulted": "none",
    "description_of_assault": "",
    "location_assault_occurred": ""
  }
]

---
DOCUMENT TEXT STARTS HERE:
{document_text}
---
DOCUMENT TEXT ENDS HERE.

Now, provide the JSON output.
"""

# %%
from googleapiclient.discovery import build
import io

# --- CONFIGURATION ---
FOLDER_ID = '1YTgvA06s-Q9NWsR_0l4y8xfcW2tRFXHv' # PASTE YOUR GOOGLE DRIVE FOLDER ID HERE
SPREADSHEET_ID = '1HeU9yBYm79EKEbqz9oCQnBTRFr_AQym5KFA8CFVG-uQ' # PASTE YOUR GOOGLE SHEET ID HERE
# ---------------------

# Set up the Gemini model with strict JSON output
model = genai.GenerativeModel(
    'gemini-1.5-flash',
    generation_config=genai.GenerationConfig(
        response_mime_type="application/json" # This is the key addition!
    )
)

# Set up services
drive_service = build('drive', 'v3', credentials=creds)
# Open the spreadsheet by ID instead of name for robustness
spreadsheet = gc.open_by_key(SPREADSHEET_ID)
worksheet = spreadsheet.sheet1 # Assuming you're working on the first sheet

print(f"Successfully connected to spreadsheet with ID: '{SPREADSHEET_ID}'")

# Get list of files from Google Drive
query = f"'{FOLDER_ID}' in parents and mimeType='application/pdf'"
results = drive_service.files().list(q=query, fields="files(id, name)").execute()
items = results.get('files', [])

if not items:
    print("No files found in the specified folder.")
else:
    print(f"Found {len(items)} PDF documents to process.")
    for item in items:
        file_id = item['id']
        file_name = item['name']
        print(f"\n--- Processing: {file_name} ---")

        try:
            # Download and read PDF content
            request = drive_service.files().get_media(fileId=file_id)
            pdf_raw_data = request.execute()
            pdf_reader = PdfReader(io.BytesIO(pdf_raw_data))

            document_text = ""
            for page in pdf_reader.pages:
                document_text += page.extract_text() or ""

            if not document_text.strip():
                print("  - Could not extract text from this PDF (it might be an image or empty). Skipping.")
                continue

            # Send to Gemini
            prompt = MASTER_PROMPT.format(document_text=document_text[:100000])
            response = model.generate_content(prompt)

            # Clean and parse the JSON response
            # With response_mime_type, the replace calls might be less necessary,
            # but they don't hurt and provide a layer of robustness.
            cleaned_response = response.text.strip().replace('```json', '').replace('```', '').strip()

            # --- DEBUGGING PRINT STATEMENT (UNCOMMENTED) ---
            # This will show you the exact string json.loads() is trying to parse
            # Keep it uncommented for the next run to see if the fix worked
            # and what the response looks like now.
            # You can comment it out after you confirm it's working as expected.
            # print(f"  --- Raw Gemini response for {file_name}:\n{cleaned_response}\n---")
            # ----------------------------------------------

            officer_data = json.loads(cleaned_response)

            if not officer_data:
                print("  - No officers found in this document based on the prompt criteria.")
            else:
                print(f"  - Found {len(officer_data)} officer(s). Writing to sheet...")
                for officer in officer_data:
                    row_to_add = [
                        officer.get('full_name', ''),
                        officer.get('initials_identifier', ''),
                        officer.get('agency', 'Unknown'),
                        officer.get('job_title', ''),
                        officer.get('assaulted', 'unknown'),
                        officer.get('description_of_assault', ''),
                        officer.get('location_assault_occurred', ''),
                        file_name
                    ]
                    worksheet.append_row(row_to_add)

            time.sleep(1)

        except json.JSONDecodeError as e:
            print(f"  *** JSON error while processing {file_name}: {e} ***")
            # Print a bit more of the problematic response to see if the issue changed
            print(f"  *** Gemini's problematic response (start of string): '{cleaned_response[:500]}' ***")
            print("  *** Skipping this file. ***")
        except Exception as e:
            print(f"  *** An error occurred while processing {file_name}: {e} ***")
            print("  *** Skipping this file. ***")

print("\n\n--- All documents processed! ---")
# Out:
# Successfully connected to spreadsheet with ID: '1HeU9yBYm79EKEbqz9oCQnBTRFr_AQym5KFA8CFVG-uQ'
# Found 100 PDF documents to process.
#
# --- Processing: zerkle_jacob_statement_of_facts.pdf ---
#   *** An error occurred while processing zerkle_jacob_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: young_philip_statement_of_offense.pdf ---
#   *** An error occurred while processing young_philip_statement_of_offense.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: young_philip_indictment.pdf ---
#   *** An error occurred while processing young_philip_indictment.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: young_philip_unopposed_government_motion_to_strike_portions_of_indictment.pdf ---
#   *** An error occurred while processing young_philip_unopposed_government_motion_to_strike_portions_of_indictment.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: young_philip_statement_of_facts.pdf ---
#   *** An error occurred while processing young_philip_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: young_kyle_indictment_2.pdf ---
#   *** An error occurred while processing young_kyle_indictment_2.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: young_kyle_charges_doc.pdf ---
#   *** An error occurred while processing young_kyle_charges_doc.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: young_kyle_indictment.pdf ---
#   *** An error occurred while processing young_kyle_indictment.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: young_kyle_statement_of_offense.pdf ---
#   *** An error occurred while processing young_kyle_statement_of_offense.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: yetman_gregory_statement_of_facts.pdf ---
#   *** An error occurred while processing yetman_gregory_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: wyatt_douglas_statement_of_facts.pdf ---
#   *** An error occurred while processing wyatt_douglas_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: wren_donnie_transcript.pdf ---
#   *** An error occurred while processing wren_donnie_transcript.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: wren_donnie_indictment.pdf ---
#   *** An error occurred while processing wren_donnie_indictment.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: worrell_christopher_indictment.pdf ---
#   *** An error occurred while processing worrell_christopher_indictment.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: worrell_christopher_statement_of_facts.pdf ---
#   *** An error occurred while processing worrell_christopher_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: woods_shane_indictment_2.pdf ---
#   *** An error occurred while processing woods_shane_indictment_2.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: woods_shane_indictment.pdf ---
#   *** An error occurred while processing woods_shane_indictment.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: woods_shane_statement_of_offense.pdf ---
#   *** An error occurred while processing woods_shane_statement_of_offense.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: woods_shane_affidavit.pdf ---
#   *** An error occurred while processing woods_shane_affidavit.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: woods_shane_charges_doc.pdf ---
#   *** An error occurred while processing woods_shane_charges_doc.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: wilson_duke_indictment.pdf ---
#   *** An error occurred while processing wilson_duke_indictment.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: wilson_duke_statement_of_offense.pdf ---
#   *** An error occurred while processing wilson_duke_statement_of_offense.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: wilson_duke_charges_doc.pdf ---
#   *** An error occurred while processing wilson_duke_charges_doc.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: wilson_duke_affidavit.pdf ---
#   *** An error occurred while processing wilson_duke_affidavit.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: williams_dustin_statement_of_facts.pdf ---
#   *** An error occurred while processing williams_dustin_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: williams_riley_statement_of_facts_2.pdf ---
#   *** An error occurred while processing williams_riley_statement_of_facts_2.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: williams_riley_indictment.pdf ---
#   *** An error occurred while processing williams_riley_indictment.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: williams_riley_statement_of_facts.pdf ---
#   *** An error occurred while processing williams_riley_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: willden_ricky_statement_of_offense.pdf ---
#   *** An error occurred while processing willden_ricky_statement_of_offense.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: wilden_ricky_indictment.pdf ---
#   *** An error occurred while processing wilden_ricky_indictment.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: willden_ricky_charges_doc.pdf ---
#   *** An error occurred while processing willden_ricky_charges_doc.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: willden_ricky_indictment.pdf ---
#   - Could not extract text from this PDF (it might be an image or empty). Skipping.
#
# --- Processing: whitton_jr_jack_charges_doc.pdf ---
#   *** An error occurred while processing whitton_jr_jack_charges_doc.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: whitton_jr_jack_indictment_2.pdf ---
#   - Could not extract text from this PDF (it might be an image or empty). Skipping.
#
# --- Processing: whitton_jr_jack_indictment.pdf ---
#   *** An error occurred while processing whitton_jr_jack_indictment.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: whitton_jr_jack_statement_of_offense.pdf ---
#   *** An error occurred while processing whitton_jr_jack_statement_of_offense.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: weston_tucker_affidavit.pdf ---
#   *** An error occurred while processing weston_tucker_affidavit.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: weeks_troy_indictment.pdf ---
#   *** An error occurred while processing weeks_troy_indictment.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: weeks_troy_statement_of_facts.pdf ---
#   *** An error occurred while processing weeks_troy_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: webster_thomas_statement_of_facts.pdf ---
#   *** An error occurred while processing webster_thomas_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: webster_thomas_indictment_2.pdf ---
#   - Could not extract text from this PDF (it might be an image or empty). Skipping.
#
# --- Processing: webster_thomas_indictment.pdf ---
#   *** An error occurred while processing webster_thomas_indictment.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: waynick_jerry_statement_of_facts.pdf ---
#   *** An error occurred while processing waynick_jerry_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: waynick_mark_statement_of_facts.pdf ---
#   *** An error occurred while processing waynick_mark_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: vournas_tom_statement_of_offense.pdf ---
#   *** An error occurred while processing vournas_tom_statement_of_offense.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: vassallo_salvatore_statement_of_facts.pdf ---
#   *** An error occurred while processing vassallo_salvatore_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: valentin_matthew_statement_of_facts_2.pdf ---
#   *** An error occurred while processing valentin_matthew_statement_of_facts_2.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: valentin_matthew_statement_of_facts.pdf ---
#   *** An error occurred while processing valentin_matthew_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: turner_robert_statement_of_facts.pdf ---
#   *** An error occurred while processing turner_robert_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: tryon_castro_casey_statement_of_facts.pdf ---
#   *** An error occurred while processing tryon_castro_casey_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: tryon_castro_casey_indictment.pdf ---
#   *** An error occurred while processing tryon_castro_casey_indictment.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: thompson_devlyn_charges_doc.pdf ---
#   *** An error occurred while processing thompson_devlyn_charges_doc.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: thompson_devlyn_statement_of_offense.pdf ---
#   *** An error occurred while processing thompson_devlyn_statement_of_offense.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: thompson_devlyn_indictment.pdf ---
#   *** An error occurred while processing thompson_devlyn_indictment.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: thomas_kenneth_statement_of_facts.pdf ---
#   *** An error occurred while processing thomas_kenneth_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: therres_jacob_charges_doc.pdf ---
#   *** An error occurred while processing therres_jacob_charges_doc.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: tate_curtis_statement_of_facts.pdf ---
#   *** An error occurred while processing tate_curtis_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: taake_andrew_statement_of_facts.pdf ---
#   *** An error occurred while processing taake_andrew_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: swoope_ryan_statement_of_facts.pdf ---
#   *** An error occurred while processing swoope_ryan_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: sturgeon_isaac_indictment.pdf ---
#   *** An error occurred while processing sturgeon_isaac_indictment.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: stevens_tristan_indictment_4.pdf ---
#   *** An error occurred while processing stevens_tristan_indictment_4.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: stevens_tristan_indictment_3.pdf ---
#   *** An error occurred while processing stevens_tristan_indictment_3.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: stevens_tristan_indictment_2.pdf ---
#   *** An error occurred while processing stevens_tristan_indictment_2.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: stevens_tristan_affidavit.pdf ---
#   *** An error occurred while processing stevens_tristan_affidavit.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: stevens_tristan_indictment.pdf ---
#   *** An error occurred while processing stevens_tristan_indictment.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: starer_jacqueline_statement_of_facts.pdf ---
#   *** An error occurred while processing starer_jacqueline_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: stager_peter_indictment_4.pdf ---
#   - Could not extract text from this PDF (it might be an image or empty). Skipping.
#
# --- Processing: stager_peter_indictment_3.pdf ---
#   *** An error occurred while processing stager_peter_indictment_3.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: stager_peter_statement_of_facts_2.pdf ---
#   *** An error occurred while processing stager_peter_statement_of_facts_2.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: stager_peter_statement_of_facts.pdf ---
#   *** An error occurred while processing stager_peter_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: stager_peter_indictment_2.pdf ---
#   - Could not extract text from this PDF (it might be an image or empty). Skipping.
#
# --- Processing: stager_peter_indictment.pdf ---
#   - Could not extract text from this PDF (it might be an image or empty). Skipping.
#
# --- Processing: southard_rumsey_audrey_indictment_2.pdf ---
#   - Could not extract text from this PDF (it might be an image or empty). Skipping.
#
# --- Processing: southard_rumsey_audrey_indictment.pdf ---
#   *** An error occurred while processing southard_rumsey_audrey_indictment.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: southard_rumsey_audrey_statement_of_facts.pdf ---
#   *** An error occurred while processing southard_rumsey_audrey_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: smotherman_nicholas_statement_of_offense.pdf ---
#   *** An error occurred while processing smotherman_nicholas_statement_of_offense.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: smith_charles_indictment.pdf ---
#   *** An error occurred while processing smith_charles_indictment.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: smith_charles_statement_of_offense.pdf ---
#   - Could not extract text from this PDF (it might be an image or empty). Skipping.
#
# --- Processing: smith_charles_charges_doc.pdf ---
#   - Could not extract text from this PDF (it might be an image or empty). Skipping.
#
# --- Processing: smith_thomas_indictment.pdf ---
#   *** An error occurred while processing smith_thomas_indictment.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: smith_bryan_statement_of_facts.pdf ---
#   *** An error occurred while processing smith_bryan_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: slye_mikhail_statement_of_facts.pdf ---
#   *** An error occurred while processing slye_mikhail_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: clye_mikhail_charges_doc.pdf ---
#   *** An error occurred while processing clye_mikhail_charges_doc.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: sills_geoffrey_statement_of_facts.pdf ---
#   *** An error occurred while processing sills_geoffrey_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: sills_geoffrey_indictment.pdf ---
#   *** An error occurred while processing sills_geoffrey_indictment.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: sibick_thomas_statement_of_facts.pdf ---
#   *** An error occurred while processing sibick_thomas_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: shively_barton_statement_of_facts.pdf ---
#   *** An error occurred while processing shively_barton_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: shively_barton_indictment_2.pdf ---
#   - Could not extract text from this PDF (it might be an image or empty). Skipping.
#
# --- Processing: shively_barton_statement_of_offense.pdf ---
#   - Could not extract text from this PDF (it might be an image or empty). Skipping.
#
# --- Processing: shively_barton_indictment.pdf ---
#   *** An error occurred while processing shively_barton_indictment.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: shively_barton_charges_doc.pdf ---
#   *** An error occurred while processing shively_barton_charges_doc.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: sherrill_grayson_indictment.pdf ---
#   - Could not extract text from this PDF (it might be an image or empty). Skipping.
#
# --- Processing: sherrill_grayson_statement_of_facts.pdf ---
#   *** An error occurred while processing sherrill_grayson_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: sherrill_grayson_indictment (2).pdf ---
#   *** An error occurred while processing sherrill_grayson_indictment (2).pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: sherrill_grayson_charges_doc.pdf ---
#   *** An error occurred while processing sherrill_grayson_charges_doc.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: shalvey_dale_statement_of_facts.pdf ---
#   *** An error occurred while processing shalvey_dale_statement_of_facts.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: shalvey_dale_indictment_5.pdf ---
#   - Could not extract text from this PDF (it might be an image or empty). Skipping.
#
# --- Processing: shalvey_dale_indictment_4.pdf ---
#   *** An error occurred while processing shalvey_dale_indictment_4.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: shalvey_dale_statement_of_offense.pdf ---
#   *** An error occurred while processing shalvey_dale_statement_of_offense.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
# --- Processing: shalvey_dale_indictment_3.pdf ---
#   *** An error occurred while processing shalvey_dale_indictment_3.pdf: '\n    "full_name"' ***
#   *** Skipping this file. ***
#
#
# --- All documents processed! ---
